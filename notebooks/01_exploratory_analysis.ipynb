# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Initial exploration of the protein sequence dataset.
# Goals:
# - Understand class distribution
# - Inspect sequence length distribution
# - Spot data quality issues (non-standard residues, duplicates)
# - Visualise basic physicochemical statistics

# %%
import sys
sys.path.insert(0, '..')  # allow importing from src/

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Load dataset
# TODO: update paths to point at your actual data files.

# %%
# TODO: replace with real paths
SEQUENCES_PATH = '../data/raw/sequences.fasta'
LABELS_PATH    = '../data/raw/labels.csv'

# from src.data.loader import load_dataset
# df = load_dataset(SEQUENCES_PATH, LABELS_PATH)
# df.head()

# %% [markdown]
# ## 2. Class distribution

# %%
# TODO: uncomment once df is loaded
# fig, ax = plt.subplots(figsize=(10, 4))
# df['label'].value_counts().plot(kind='bar', ax=ax)
# ax.set_title('Class distribution')
# ax.set_xlabel('Function label')
# ax.set_ylabel('Count')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 3. Sequence length distribution

# %%
# TODO: uncomment once df is loaded
# df['seq_len'] = df['sequence'].str.len()
# df['seq_len'].describe()

# %%
# TODO: plot sequence length histogram
# fig, ax = plt.subplots()
# df['seq_len'].hist(bins=50, ax=ax)
# ax.set_xlabel('Sequence length (AA)')
# ax.set_ylabel('Count')
# plt.show()

# %% [markdown]
# ## 4. Amino acid composition

# %%
# TODO: compute per-AA frequency across the whole dataset
# from collections import Counter
# all_residues = ''.join(df['sequence'])
# counts = Counter(all_residues)
# aa_df = pd.DataFrame(counts.items(), columns=['AA', 'count']).sort_values('AA')
# aa_df.plot(x='AA', y='count', kind='bar', legend=False)

# %% [markdown]
# ## 5. Data quality checks

# %%
# TODO: check for duplicate sequences
# print('Duplicate sequences:', df['sequence'].duplicated().sum())

# TODO: check for non-standard residues
# STANDARD_AAS = set('ACDEFGHIKLMNPQRSTVWY')
# has_nonstandard = df['sequence'].apply(lambda s: bool(set(s) - STANDARD_AAS))
# print('Sequences with non-standard residues:', has_nonstandard.sum())
